# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df = pd.read_csv('sgjobdata.csv.xz')

# %%
df.head()
# Out:
#                                           categories employmentTypes  \
# 0  [{"id":13,"category":"Environment / Health"},{...       Permanent
# 1    [{"id":21,"category":"Information Technology"}]       Permanent
# 2    [{"id":33,"category":"Repair and Maintenance"}]       Full Time
# 3    [{"id":21,"category":"Information Technology"}]       Permanent
# 4        [{"id":2,"category":"Admin / Secretarial"}]       Full Time
#
#   metadata_expiryDate  metadata_isPostedOnBehalf metadata_jobPostId  \
# 0          2023-05-08                      False   MCF-2023-0252866
# 1          2023-05-08                      False   MCF-2023-0273977
# 2          2023-04-22                      False   MCF-2023-0273994
# 3          2023-05-08                      False   MCF-2023-0273991
# 4          2023-05-08                      False   MCF-2023-0273976
#
#   metadata_newPostingDate metadata_originalPostingDate  metadata_repostCount  \
# 0              2023-04-08                   2023-03-30                     2
# 1              2023-04-08                   2023-04-08                     0
# 2              2023-04-08                   2023-04-08                     0
# 3              2023-04-08                   2023-04-08                     0
# 4              2023-04-08                   2023-04-08                     0
#
#    metadata_totalNumberJobApplication  metadata_totalNumberOfView  ...  \
# 0                                   5                         151  ...
# 1                                   0                          55  ...
# 2                                   7                          99  ...
# 3                                   6                         113  ...
# 4                                   3                          99  ...
#
#    occupationId    positionLevels                postedCompany_name  \
# 0           NaN         Executive               WORKSTONE PTE. LTD.
# 1           NaN         Executive           TRUST RECRUIT PTE. LTD.
# 2           NaN  Senior Executive        PU TIEN SERVICES PTE. LTD.
# 3           NaN  Senior Executive           TRUST RECRUIT PTE. LTD.
# 4           NaN     Non-executive  EATZ CATERING SERVICES PTE. LTD.
#
#   salary_maximum salary_minimum  salary_type  status_id status_jobStatus  \
# 0           2800           2000      Monthly          0           Closed
# 1           5500           4000      Monthly          0           Closed
# 2           4600           3800      Monthly          0           Closed
# 3          10000           5000      Monthly          0           Closed
# 4           3400           2400      Monthly          0           Closed
#
#                                                title average_salary
# 0  Food Technologist - Clementi | Entry Level | U...         2400.0
# 1  Software Engineer (Fab Support) (Java, CIM, Up...         4750.0
# 2                                  Senior Technician         4200.0
# 3  Senior .NET Developer (.NET Core, MVC, MVVC, S...         7500.0
# 4                           Sales / Admin Cordinator         2900.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048585 entries, 0 to 1048584
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   categories                          1044597 non-null  object
#  1   employmentTypes                     1044597 non-null  object
#  2   metadata_expiryDate                 1044597 non-null  object
#  3   metadata_isPostedOnBehalf           1048585 non-null  bool
#  4   metadata_jobPostId                  1044597 non-null  object
#  5   metadata_newPostingDate             1044597 non-null  object
#  6   metadata_originalPostingDate        1044597 non-null  object
#  7   metadata_repostCount                1048585 non-null  int64
#  8   metadata_totalNumberJobApplication  1048585 non-null  int64
#  9   metadata_totalNumberOfView          1048585 non-null  int64
#  10  minimumYearsExperience              1048585 non-null  int64
#  11  numberOfVacancies                   1048585 non-null  int64
#  12  occupationId                        0 non-null        float64
#  13  positionLevels                      1044597 non-null  object
#  14  postedCompany_name                  1044597 non-null  object
#  15  salary_maximum                      1048585 non-null  int64
#  16  salary_minimum                      1048585 non-null  int64
#  17  salary_type                         1044597 non-null  object
#  18  status_id                           1048585 non-null  int64
#  19  status_jobStatus                    1044597 non-null  object
#  20  title                               1044597 non-null  object
#  21  average_salary                      1048585 non-null  float64
# dtypes: bool(1), float64(2), int64(8), object(11)
# memory usage: 169.0+ MB

# %%
def explode_categories(df, col="categories"):
    out = df.copy()

    out[col] = (
        out[col]
        .dropna()
        .map(lambda x: json.loads(x) if isinstance(x, str) else x)
    )

    out = out.explode(col, ignore_index=True)

    out["category_id"] = out[col].map(lambda d: d.get("id") if isinstance(d, dict) else None)
    out["category"]    = out[col].map(lambda d: d.get("category") if isinstance(d, dict) else None)

    return out.drop(columns=[col])

df_exploded = explode_categories(df)
df_exploded.head()
# Out:
#   employmentTypes metadata_expiryDate  metadata_isPostedOnBehalf  \
# 0       Permanent          2023-05-08                      False
# 1       Permanent          2023-05-08                      False
# 2       Permanent          2023-05-08                      False
# 3       Permanent          2023-05-08                      False
# 4       Full Time          2023-04-22                      False
#
#   metadata_jobPostId metadata_newPostingDate metadata_originalPostingDate  \
# 0   MCF-2023-0252866              2023-04-08                   2023-03-30
# 1   MCF-2023-0252866              2023-04-08                   2023-03-30
# 2   MCF-2023-0252866              2023-04-08                   2023-03-30
# 3   MCF-2023-0273977              2023-04-08                   2023-04-08
# 4   MCF-2023-0273994              2023-04-08                   2023-04-08
#
#    metadata_repostCount  metadata_totalNumberJobApplication  \
# 0                     2                                   5
# 1                     2                                   5
# 2                     2                                   5
# 3                     0                                   0
# 4                     0                                   7
#
#    metadata_totalNumberOfView  minimumYearsExperience  ...  \
# 0                         151                       0  ...
# 1                         151                       0  ...
# 2                         151                       0  ...
# 3                          55                       2  ...
# 4                          99                       3  ...
#
#            postedCompany_name  salary_maximum salary_minimum salary_type  \
# 0         WORKSTONE PTE. LTD.            2800           2000     Monthly
# 1         WORKSTONE PTE. LTD.            2800           2000     Monthly
# 2         WORKSTONE PTE. LTD.            2800           2000     Monthly
# 3     TRUST RECRUIT PTE. LTD.            5500           4000     Monthly
# 4  PU TIEN SERVICES PTE. LTD.            4600           3800     Monthly
#
#    status_id  status_jobStatus  \
# 0          0            Closed
# 1          0            Closed
# 2          0            Closed
# 3          0            Closed
# 4          0            Closed
#
#                                                title  average_salary  \
# 0  Food Technologist - Clementi | Entry Level | U...          2400.0
# 1  Food Technologist - Clementi | Entry Level | U...          2400.0
# 2  Food Technologist - Clementi | Entry Level | U...          2400.0
# 3  Software Engineer (Fab Support) (Java, CIM, Up...          4750.0
# 4                                  Senior Technician          4200.0
#
#   category_id                     category
# 0        13.0         Environment / Health
# 1        25.0                Manufacturing
# 2        36.0  Sciences / Laboratory / R&D
# 3        21.0       Information Technology
# 4        33.0       Repair and Maintenance
#
# [5 rows x 23 columns]

# %%
# if company name contains 'kpmg', show list of such rows
df_exploded[df_exploded['postedCompany_name'].str.contains('kpmg', case=False, na=False)].sort_values('metadata_originalPostingDate', ascending=False)
# Out:
#         employmentTypes metadata_expiryDate  metadata_isPostedOnBehalf  \
# 1769536       Full Time          2024-06-28                      False
# 1768215       Permanent          2024-06-27                      False
# 1763261       Full Time          2024-06-27                      False
# 1767911       Permanent          2024-06-27                      False
# 1767937       Permanent          2024-06-27                      False
# ...                 ...                 ...                        ...
# 91654         Permanent          2023-06-22                      False
# 91652         Permanent          2023-06-22                      False
# 255377        Full Time          2023-07-28                      False
# 255378        Full Time          2023-07-28                      False
# 255379        Full Time          2023-07-28                      False
#
#         metadata_jobPostId metadata_newPostingDate  \
# 1769536   MCF-2024-0778628              2024-05-29
# 1768215   MCF-2024-0772530              2024-05-28
# 1763261   MCF-2024-0771384              2024-05-28
# 1767911   MCF-2024-0772873              2024-05-28
# 1767937   MCF-2024-0772888              2024-05-28
# ...                    ...                     ...
# 91654     MCF-2023-0054535              2023-05-23
# 91652     MCF-2023-0054535              2023-05-23
# 255377    MCF-2023-0024812              2023-06-28
# 255378    MCF-2023-0024812              2023-06-28
# 255379    MCF-2023-0024812              2023-06-28
#
#         metadata_originalPostingDate  metadata_repostCount  \
# 1769536                   2024-05-29                     0
# 1768215                   2024-05-28                     0
# 1763261                   2024-05-28                     0
# 1767911                   2024-05-28                     0
# 1767937                   2024-05-28                     0
# ...                              ...                   ...
# 91654                     2023-01-19                     1
# 91652                     2023-01-19                     1
# 255377                    2023-01-10                     1
# 255378                    2023-01-10                     1
# 255379                    2023-01-10                     1
#
#          metadata_totalNumberJobApplication  metadata_totalNumberOfView  \
# 1769536                                   1                           7
# 1768215                                   1                           8
# 1763261                                   0                           1
# 1767911                                   1                          11
# 1767937                                   1                          13
# ...                                     ...                         ...
# 91654                                    10                         150
# 91652                                    10                         150
# 255377                                   33                         307
# 255378                                   33                         307
# 255379                                   33                         307
#
#          minimumYearsExperience  ...       postedCompany_name  salary_maximum  \
# 1769536                       1  ...  KPMG SERVICES PTE. LTD.            5000
# 1768215                       8  ...  KPMG SERVICES PTE. LTD.           15500
# 1763261                       1  ...  KPMG SERVICES PTE. LTD.            5000
# 1767911                       6  ...  KPMG SERVICES PTE. LTD.           12000
# 1767937                      10  ...  KPMG SERVICES PTE. LTD.           15500
# ...                         ...  ...                      ...             ...
# 91654                        10  ...  KPMG SERVICES PTE. LTD.           15000
# 91652                        10  ...  KPMG SERVICES PTE. LTD.           15000
# 255377                        7  ...  KPMG SERVICES PTE. LTD.           18000
# 255378                        7  ...  KPMG SERVICES PTE. LTD.           18000
# 255379                        7  ...  KPMG SERVICES PTE. LTD.           18000
#
#         salary_minimum salary_type  status_id  status_jobStatus  \
# 1769536           3000     Monthly          0              Open
# 1768215           8000     Monthly          0              Open
# 1763261           3000     Monthly          0              Open
# 1767911           6500     Monthly          0              Open
# 1767937           8000     Monthly          0              Open
# ...                ...         ...        ...               ...
# 91654             7500     Monthly          0            Closed
# 91652             7500     Monthly          0            Closed
# 255377            9000     Monthly          0           Re-open
# 255378            9000     Monthly          0           Re-open
# 255379            9000     Monthly          0           Re-open
#
#                                                      title  average_salary  \
# 1769536  Personal Tax & Global Mobility Services, Assoc...          4000.0
# 1768215               Indirect Tax, Manager/Senior Manager         11750.0
# 1763261                            Indirect Tax, Associate          4000.0
# 1767911  Corporate Tax Planning & Compliance, Assistant...          9250.0
# 1767937  Corporate Tax Planning and Compliance - Manage...         11750.0
# ...                                                    ...             ...
# 91654    Risk Consulting, Digital Trust, Associate Dire...         11250.0
# 91652    Risk Consulting, Digital Trust, Associate Dire...         11250.0
# 255377         ESG Hub - Associate Director, ESG Alliances         13500.0
# 255378         ESG Hub - Associate Director, ESG Alliances         13500.0
# 255379         ESG Hub - Associate Director, ESG Alliances         13500.0
#
#         category_id                          category
# 1769536         1.0  Accounting / Auditing / Taxation
# 1768215         1.0  Accounting / Auditing / Taxation
# 1763261         1.0  Accounting / Auditing / Taxation
# 1767911         1.0  Accounting / Auditing / Taxation
# 1767937         1.0  Accounting / Auditing / Taxation
# ...             ...                               ...
# 91654          21.0            Information Technology
# 91652           1.0  Accounting / Auditing / Taxation
# 255377         26.0      Marketing / Public Relations
# 255378         29.0             Professional Services
# 255379         35.0                    Sales / Retail
#
# [656 rows x 23 columns]

# %%
df_exploded.category.value_counts()
# Out:
# category
# Information Technology               140866
# Engineering                          136372
# Admin / Secretarial                  117854
# Customer Service                     111785
# Others                               106101
# Sales / Retail                       105067
# Building and Construction             84034
# Accounting / Auditing / Taxation      78648
# F&B                                   73731
# Logistics / Supply Chain              69193
# Banking and Finance                   62000
# Manufacturing                         56437
# Human Resources                       53465
# Marketing / Public Relations          53442
# Healthcare / Pharmaceutical           52741
# Education and Training                44877
# Consulting                            38961
# General Management                    35397
# General Work                          30140
# Hospitality                           25165
# Repair and Maintenance                23791
# Professional Services                 20221
# Sciences / Laboratory / R&D           19753
# Advertising / Media                   19584
# Design                                18512
# Environment / Health                  17211
# Events / Promotions                   16993
# Personal Care / Beauty                16932
# Purchasing / Merchandising            15382
# Architecture / Interior Design        15353
# Medical / Therapy Services            15351
# Wholesale Trade                       11091
# Legal                                 10737
# Real Estate / Property Management     10513
# Risk Management                        9390
# Social Services                        8684
# Insurance                              7994
# Telecommunications                     7964
# Precision Engineering                  6562
# Travel / Tourism                       6549
# Security and Investigation             5461
# Entertainment                          4242
# Public / Civil Service                 3283
# Name: count, dtype: int64

# %%
df_exploded[df_exploded['category'] == 'Accounting / Auditing / Taxation'][['category','postedCompany_name','metadata_jobPostId','numberOfVacancies']] #\
    #.groupby('postedCompany_name').numberOfVacancies.sum().sort_values(ascending=False)
# Out:
#                                  category  \
# 12       Accounting / Auditing / Taxation
# 26       Accounting / Auditing / Taxation
# 60       Accounting / Auditing / Taxation
# 80       Accounting / Auditing / Taxation
# 107      Accounting / Auditing / Taxation
# ...                                   ...
# 1771705  Accounting / Auditing / Taxation
# 1771708  Accounting / Auditing / Taxation
# 1771723  Accounting / Auditing / Taxation
# 1771742  Accounting / Auditing / Taxation
# 1771773  Accounting / Auditing / Taxation
#
#                           postedCompany_name  \
# 12                       WORKSTONE PTE. LTD.
# 26                       WORKSTONE PTE. LTD.
# 60                       WORKSTONE PTE. LTD.
# 80           VALENCY INTERNATIONAL PTE. LTD.
# 107                   RECRUITPEDIA PTE. LTD.
# ...                                      ...
# 1771705               RECRUITPEDIA PTE. LTD.
# 1771708  THE INCEPTION RECRUITMENT PTE. LTD.
# 1771723               RECRUITPEDIA PTE. LTD.
# 1771742               RECRUITPEDIA PTE. LTD.
# 1771773         BOND CAPITAL GROUP PTE. LTD.
#
#                         metadata_jobPostId  numberOfVacancies
# 12                        MCF-2023-0261996                  1
# 26                        MCF-2023-0273998                  1
# 60                        MCF-2023-0261994                  1
# 80                        MCF-2023-0274151                  1
# 107                       MCF-2023-0274059                  1
# ...                                    ...                ...
# 1771705                   MCF-2024-0783885                  1
# 1771708                   MCF-2024-0783871                  2
# 1771723                   MCF-2024-0783881                  1
# 1771742                   MCF-2024-0783842                  1
# 1771773  RANDOM_JOB_20251115011346015685_0                579
#
# [78648 rows x 4 columns]
